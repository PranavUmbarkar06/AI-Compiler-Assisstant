# %%
# Out:
# [('INT', 'integer'),
#  ('ID', 'pranav'),
#  ('ASSIGN', '='),
#  ('NUMBER', '5'),
#  ('SEMICOLON', ';'),
#  ('PRINT', 'print'),
#  ('LPAREN', '('),
#  ('ID', 'pranav'),
#  ('RPAREN', ')'),
#  ('EOF', '')]

# %%
# Out:
# ====== Mini-C Compiler with AI Assistant ======
#
#
# Enter your code line by line (type 'exit' to finish input):
# No code entered. Exiting...

# %%
from Compiler import Lexer as l,Parser as p,Evaluator as e,ai_assistant as ai


code=open('main','r').read()
def refine_code(code):
    new_code=''
    for i in code:
        if i in ['\n']:
            new_code+=' '
            continue
        new_code+=i
    return new_code

code=refine_code(code)
try:
    
    tokens=l.lexer(code)
    parser = p.Parser(tokens)
    ast_root = parser.parse_program()
    interp=e.Interpreter()
    interp.eval(ast_root)

    print(interp)

except SyntaxError:
    


# prompt_query = f"{code}"
# system_role = "Act as a passionate, concise space enthusiast."

# result = ai.check_api_and_generate(prompt_query, system_instruction=system_role)
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[14], line 18
#     ast_root = parser.parse_program()
#
#   File c:\Users\Pranav\Desktop\College\Projects\aiCompilerAssisstant\Compiler\Parser.py:24 in parse_program
#     stmts.append(self.parse_stmt())
#
#   File c:\Users\Pranav\Desktop\College\Projects\aiCompilerAssisstant\Compiler\Parser.py:30 in parse_stmt
#     return self.parse_decl()
#
#   File c:\Users\Pranav\Desktop\College\Projects\aiCompilerAssisstant\Compiler\Parser.py:44 in parse_decl
#     self.eat('SEMICOLON')
#
#   File c:\Users\Pranav\Desktop\College\Projects\aiCompilerAssisstant\Compiler\Parser.py:19 in eat
#     raise SyntaxError(f"Expected {token_type}, got {self.peek()}")
#
#   File <string>
# SyntaxError: Expected SEMICOLON, got ('PRINT', 'print')

# %%
from Compiler import OfflineAssistant as off,OnlineAssistant as on
# -----------------------------------------------------------
import re 
import sys


def refine_code(code):
    new_code=''
    for i in code:
        if i in ['\n']:
            new_code+=' '
            continue
        new_code+=i
    return new_code


if __name__ == '__main__':


    code=open('main','r').read()
    code=refine_code(code)
    print(code)
    
    #ONLINE
    prompt_query = f"""
    Below is the complete Python code implementing a custom language compiler/interpreter, featuring a Lexer, Parser (Recursive Descent), and an Interpreter.

    The language supports:
    - Variable declaration (integer x = 10;)
    - Assignment (x = 20;)
    - Integer arithmetic (+, -, *, / with integer division)
    - Printing strings and expressions (print("Hello"); print(x + 1);)
    - Parentheses for precedence.

    Please analyze the provided code and give structured, actionable feedback focusing on the following areas:

    ---

    ## 1. Code Optimizations and Performance Suggestions 🚀
    Identify specific lines or components in the Lexer, Parser, or Interpreter that could be refactored for better performance or Pythonic clarity.
    - **Lexer:** Are the regex patterns efficient, or could the token definition order be improved?
    - **Interpreter:** Are there data structure changes that could speed up variable lookups (though the current global scope is simple)?

    ---

    ## 2. Robustness and Error Handling Suggestions 🛡️
    Point out potential runtime errors, type-checking issues, or logical flaws that the current implementation doesn't fully guard against.
    - **Type System:** The current language is only for integers. Suggest how to enforce the 'integer' type during **Assignment** to prevent bugs like `x = "hello";` if the parser was extended to allow un-declared string assignments.
    - **Ambiguity/Syntax:** Are there any cases where the grammar might lead to unexpected parsing (e.g., precedence issues, although arithmetic precedence seems correct)?
    - **Declaration/Redeclaration:** What happens if a user tries `integer x = 5; integer x = 10;`? Suggest a check to prevent this.

    ---

    ## 3. Feature Enhancements and Architecture Improvements ✨
    Suggest **three** logical, next-step features for this language and briefly describe the *minimum required changes* in each of the three components (Lexer, Parser, Interpreter) to implement them.

    1.  **Feature 1:** Conditional Statements (e.g., `if (x > 10) { ... }`)
    2.  **Feature 2:** String Concatenation (e.g., `print("Value: " + y);`)
    3.  **Feature 3:** Single-line Comments (e.g., `// This is a comment`)

    --- START OF CODE ---
    {code}
    --- End of Code

    Keep your response short,concise and clear.
    """
    system_role = "Act as a professional compiler. Give nice helpful suggestions like a nice person."
    
    result = on.online_assistant(prompt_query, system_instruction=system_role)
    print(result)
    # if result==False:
    #     analysis = off.offline_assistant(code)
    #     print("\n*** Analysis Report ***")
    #     for suggestion in analysis['suggestions']:
    #         print(suggestion)
    #     print("\n*** Runtime Output ***")
    #     print(analysis['runtime_output'])
    #     print('\n*** Final Symbol Table ***')
    #     print(analysis['final_state'])
    # else:
    
    #     print(result)
# Out:
# integer x=5; integer y=5; print(x+y);
# Request timed out. Retrying in 1 seconds...
# Request timed out. Retrying in 2 seconds...
# Hello! I'm happy to put on my compiler hat. This is a very clean and well-structured implementation for a first-pass compiler. Great work on clearly separating the Lexer, Parser, and Interpreter responsibilities.
#
# Here is the structured feedback you requested.
#
# ---
#
# ## 1. Code Optimizations and Performance Suggestions 🚀
#
# | Component | Suggestion | Rationale |
# | :--- | :--- | :--- |
# | **Lexer** | **Compile Regex Patterns** | If you are using Python's `re` module, compile all token-matching regular expressions using `re.compile()`. This pre-compiles the patterns into state machines, significantly speeding up the tokenization phase, especially for larger source files. |
# | **Lexer** | **Combine Token Matching** | Instead of running separate `re.match` checks for each token type, create a single master regex with named groups or use a tool like `re.finditer` over the entire source. This reduces overhead and is the standard practice for efficient lexing in Python. |
# | **Interpreter** | **Variable Lookup** | For the current global scope, the Python `dict` is already $O(1)$ on average for lookups, which is optimal. **No change is required.** This structure is fast and efficient for the current design. |
# | **Pythonic Refactor** | **Use Enums for Tokens** | Use Python's `enum.Enum` for defining your token types (e.g., `TokenType.PLUS`). This is more Pythonic, prevents typos, and allows for faster comparisons than using raw strings. |
#
# ---
#
# ## 2. Robustness and Error Handling Suggestions 🛡️
#
# | Area | Issue/Flaw | Suggestion/Check to Implement |
# | :--- | :--- | :--- |
# | **Declaration/Redeclaration** | Currently, `integer x = 5; integer x = 10;` is likely allowed, silently overwriting the variable. | **Parser/Interpreter Check:** During a `Declaration` statement, check the symbol table (your variable dictionary). If the identifier already exists, raise a `RedeclarationError`. |
# | **Type System Enforcement (Assignment)** | If extended, an assignment like `x = "hello";` could cause runtime errors, as `x` was declared as an integer. | **Interpreter Refactor:** Change the symbol table data structure from `{'x': 10}` to `{'x': {'type': 'integer', 'value': 10}}`. During an `Assignment` (`x = expr`), check that the result of `expr` is compatible with the stored `'type'`. |
# | **Ambiguity/Syntax** | Unary negation (e.g., `y = -5;`) can be ambiguous with binary subtraction (e.g., `y - 5;`). | **Parser Fix:** Ensure your `Factor` rule explicitly handles the unary minus operator (`-`) by giving it a higher precedence than binary operators. This typically involves checking for the minus sign token at the start of a `Factor`. |
# | **Division by Zero** | Any expression like `print(10 / 0);` will cause a standard Python runtime error. | **Interpreter Check:** During the handling of the `SLASH` operator, check the value of the right-hand operand. If it is zero, raise a custom `DivisionByZeroError` before the Python interpreter does. |
#
# ---
#
# ## 3. Feature Enhancements and Architecture Improvements ✨
#
# ### Feature 1: Conditional Statements (`if (x > 10) { ... }`)
#
# | Component | Minimum Required Change |
# | :--- | :--- |
# | **Lexer** | Add tokens for `IF`, `LBRACE` (`{`), `RBRACE` (`}`), and relational operators (`<`, `>`, `==`, etc.). |
# | **Parser** | Add a new non-terminal rule, `Condition`, which parses two expressions separated by a relational operator. Add a new `IfStatement` rule that consumes `IF`, parses a condition, and then parses a statement block (zero or more statements between `{}`). |
# | **Interpreter** | Implement logic for relational operators to return a Boolean value. The `IfStatement` handler will evaluate the condition. If true, it recursively calls the interpreter on the statement block; otherwise, it skips the block. |
#
# ### Feature 2: String Concatenation (`print("Value: " + y);`)
#
# | Component | Minimum Required Change |
# | :--- | :--- |
# | **Lexer** | **None required**, assuming `STRING` and `PLUS` tokens already exist. |
# | **Parser** | **None required**, as the `PLUS` operator already exists in the `Expression` rule. The syntax is already supported; only semantics must change. |
# | **Interpreter** | In the handler for the `PLUS` operator, check the types of the two operands. If *at least one* is a string, implicitly convert the other operand to a string (if it's an integer) and perform string concatenation. If both are integers, perform integer addition as usual. |
#
# ### Feature 3: Single-line Comments (`// This is a comment`)
#
# | Component | Minimum Required Change |
# | :--- | :--- |
# | **Lexer** | Add a new regex pattern for comments (e.g., `//.*`). Crucially, modify the lexer logic so that when a `COMMENT` token is identified, it is **discarded** and *not* passed to the parser. |
# | **Parser** | **None required**, as the Lexer will filter out comment tokens entirely, meaning the parser never sees them. |
# | **Interpreter** | **None required**, for the same reason—no comment tokens reach the execution stage. |
