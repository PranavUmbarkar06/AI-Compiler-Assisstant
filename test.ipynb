# %%
from Compiler import Lexer

code = 'integer pranav = 5; print(pranav)'

Lexer.lexer(code)
# Out:
# [('INT', 'integer'),
#  ('ID', 'pranav'),
#  ('ASSIGN', '='),
#  ('NUMBER', '5'),
#  ('SEMICOLON', ';'),
#  ('PRINT', 'print'),
#  ('LPAREN', '('),
#  ('ID', 'pranav'),
#  ('RPAREN', ')'),
#  ('EOF', '')]
